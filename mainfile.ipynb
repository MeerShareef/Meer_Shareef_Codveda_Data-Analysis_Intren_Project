# %%
import pandas as pd

# %%
iris = pd.read_csv(r"D:\codeveda project intership\Data Set For Task\1) iris.csv")

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
print(iris.isnull().sum())
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
missing_percentage = iris.isnull().mean() * 100
print(missing_percentage)
# Out:
# sepal_length    0.0
# sepal_width     0.0
# petal_length    0.0
# petal_width     0.0
# species         0.0
# dtype: float64

# %%
iris_cleaned = iris.dropna()

# %%
iris.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
iris = iris.drop_duplicates()

# %%
iris['species'] = iris['species'].str.strip().str.lower()

# %%
# Import libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load dataset
df = pd.read_csv("1) iris.csv")  # Change this if using a different file path

# Drop duplicates
df = df.drop_duplicates()

# Standardize text in species column
df['species'] = df['species'].str.strip().str.lower()

# Summary statistics
print("🔹 Summary Statistics:")
print(df.describe())

# Mode
print("\n🔹 Mode (most frequent values):")
print(df.mode().iloc[0])

# Correlation matrix
print("\n🔹 Correlation Matrix:")
print(df.corr(numeric_only=True))

# Histogram for sepal_length
plt.figure(figsize=(10, 6))
plt.subplot(2, 2, 1)
df['sepal_length'].hist(bins=15, edgecolor='black')
plt.title("Sepal Length Distribution")

# Histogram for sepal_width
plt.subplot(2, 2, 2)
df['sepal_width'].hist(bins=15, edgecolor='black')
plt.title("Sepal Width Distribution")

# Boxplot for all numeric features
plt.subplot(2, 2, 3)
sns.boxplot(data=df[['sepal_length', 'sepal_width', 'petal_length', 'petal_width']])
plt.title("Boxplot of Features")

# Scatter plot: Sepal Length vs Petal Length
plt.subplot(2, 2, 4)
sns.scatterplot(data=df, x='sepal_length', y='petal_length', hue='species')
plt.title("Sepal Length vs Petal Length")

# Adjust layout and show all plots
plt.tight_layout()
plt.show()
# Out:
# 🔹 Summary Statistics:
#        sepal_length  sepal_width  petal_length  petal_width
# count    147.000000   147.000000    147.000000   147.000000
# mean       5.856463     3.055782      3.780272     1.208844
# std        0.829100     0.437009      1.759111     0.757874
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.400000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000
#
# 🔹 Mode (most frequent values):
# sepal_length           5.0
# sepal_width            3.0
# petal_length           1.4
# petal_width            0.2
# species         versicolor
# Name: 0, dtype: object
#
# 🔹 Correlation Matrix:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.109321      0.871305     0.817058
# ...

# %%
# Import required libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
df = pd.read_csv("1) iris.csv")  # Adjust path if needed

# Drop duplicates and standardize species
df = df.drop_duplicates()
df['species'] = df['species'].str.strip().str.lower()

# === BAR PLOT: Average Petal Length by Species ===
plt.figure(figsize=(8, 5))
sns.barplot(data=df, x='species', y='petal_length')
plt.title('Average Petal Length by Species')
plt.xlabel('Species')
plt.ylabel('Petal Length (cm)')
plt.tight_layout()
plt.savefig('bar_plot_petal_length_by_species.png')  # Saves image

# === LINE CHART: Petal Width Trend over Samples ===
plt.figure(figsize=(8, 5))
for species in df['species'].unique():
    subset = df[df['species'] == species]
    plt.plot(subset.index, subset['petal_width'], label=species)

plt.title('Petal Width Trend by Species')
plt.xlabel('Sample Index')
plt.ylabel('Petal Width (cm)')
plt.legend()
plt.tight_layout()
plt.savefig('line_chart_petal_width_by_species.png')

# === SCATTER PLOT: Sepal Length vs Sepal Width ===
plt.figure(figsize=(8, 5))
sns.scatterplot(data=df, x='sepal_length', y='sepal_width', hue='species')
plt.title('Sepal Length vs Sepal Width')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Sepal Width (cm)')
plt.legend()
plt.tight_layout()
plt.savefig('scatter_plot_sepal.png')

# Show all plots (optional)
plt.show()
